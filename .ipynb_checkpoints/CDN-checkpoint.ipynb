# %%
import pandas as pd

# %%
# change the file name here
domains = pd.read_csv("./first-500/first500_haoran.csv")

# %%
domains.head()
# Out:
#          remote_hostname                   company           company_website  \
# 0  googleusercontent.com                    Google   https://www.google.com/
# 1             google.com                    Google   https://www.google.com/
# 2            gstatic.com                       NaN                       NaN
# 3             nflxso.net                   Netflix  https://www.netflix.com/
# 4            netflix.com  Streaming media provider  https://www.netflix.com/
#
#                                               result
# 0                                                CDN
# 1  {'purpose': {'marketing': True, 'advertising':...
# 2                                                NaN
# 3                                                CDN
# 4                                                CDN

# %%
cdns = domains[domains['result'] == 'CDN']

# %%
cdns.head()
# Out:
#          remote_hostname                   company  \
# 0  googleusercontent.com                    Google
# 3             nflxso.net                   Netflix
# 4            netflix.com  Streaming media provider
# 5                scdn.co                 StackPath
# 7            nflxext.com                   Netflix
#
#               company_website result
# 0     https://www.google.com/    CDN
# 3    https://www.netflix.com/    CDN
# 4    https://www.netflix.com/    CDN
# 5  https://www.stackpath.com/    CDN
# 7    https://www.netflix.com/    CDN

# %%
cdns.sample(n=20)
# Out:
#            remote_hostname              company  \
# 196         dropboxapi.com              Dropbox
# 9            amazonaws.com  Amazon Web Services
# 381             sndcdn.com           SoundCloud
# 405         brightcove.net           Brightcove
# 232        edgecastcdn.net         Edgecast CDN
# 349         ampproject.net               Google
# 362           giraffic.net             Giraffic
# 52          googleapis.com               Google
# 191             phncdn.com              Pornhub
# 253        gannett-cdn.com              Gannett
# 258         amazonsilk.com               Amazon
# 25        aiv-delivery.net  Akamai Technologies
# 219              llnwd.net   Limelight Networks
# 374            plexapp.com                 Plex
# 158           cogocast.net             Cogocast
# 32             plex.direct                 Plex
# 304             mapbox.com               Mapbox
# 14         amazonvideo.com               Amazon
# 444  githubusercontent.com               GitHub
# 170         cloudflare.net           Cloudflare
#
#                                        company_website result
# 196                            https://www.dropbox.com    CDN
# 9                              https://aws.amazon.com/    CDN
# 381                            https://soundcloud.com/    CDN
# 405                        https://www.brightcove.com/    CDN
# 232  https://www.verizondigitalmedia.com/platform/e...    CDN
# 349                            https://www.google.com/    CDN
# 362                           http://www.giraffic.com/    CDN
# 52                              https://www.google.com    CDN
# 191                           https://www.pornhub.com/    CDN
# 253                           https://www.gannett.com/    CDN
# 258                            https://www.amazon.com/    CDN
# 25                             https://www.akamai.com/    CDN
# 219                         https://www.limelight.com/    CDN
# 374                               https://www.plex.tv/    CDN
# 158                              https://cogocast.net/    CDN
# 32                                https://www.plex.tv/    CDN
# 304                            https://www.mapbox.com/    CDN
# 14                              https://www.amazon.com    CDN
# 444                                https://github.com/    CDN
# 170                        https://www.cloudflare.com/    CDN
