# %%
import pandas as pd

# %%
df = pd.read_csv('iot_class_data_class_output_hostname_df.csv')

# %%
df = df.drop('device_id', axis=1)

# %%
df = df.drop_duplicates()

# %%
df.head()
# Out:
#           remote_hostname
# 0   googleusercontent.com
# 4              google.com
# 11            gstatic.com
# 13             nflxso.net
# 14            netflix.com

# %%
df.to_csv('domains.csv', index=False)

# %%
df.count()
# Out:
# remote_hostname    3561
# dtype: int64

# %%
for i in range(0, 10):
    print(df.iloc[i]['remote_hostname'])
# Out:
# googleusercontent.com
# google.com
# gstatic.com
# nflxso.net
# netflix.com
# scdn.co
# spotify.com
# nflxext.com
# sentry-cdn.com
# amazonaws.com

# %%
df.insert(len(df.columns), 'company', "")

# %%
df.head()
# Out:
#           remote_hostname company
# 0   googleusercontent.com
# 4              google.com
# 11            gstatic.com
# 13             nflxso.net
# 14            netflix.com
