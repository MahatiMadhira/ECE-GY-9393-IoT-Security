# %%
import matplotlib.pyplot as plt

# %%
times = [395.019154548645,382.78102684020996,373.190536737442,377.93091011047363,383.13956475257874,378.00438952445984,391.964370012283,393.3709087371826,392.54962682724,394.5913391113281,387.5093297958374,384.8831992149353,393.15416526794434,390.0428512096405,410.6316804885864,385.0282280445099,381.20925068855286,308.0199885368347]

# %%
x = list(range(len(times)))

# %%
plt.plot(x, times)
plt.axis('equal')
# Out:
# (-0.8500000000000001, 17.85, 302.88940393924713, 415.762265086174)
